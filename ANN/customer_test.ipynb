# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('customer_test.csv')

# %%
df.drop(['ID'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (2627, 9)

# %%
df
# Out:
#       Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0     Female          Yes   36       Yes       Engineer              0.0
# 1       Male          Yes   37       Yes     Healthcare              8.0
# 2     Female          Yes   69        No            NaN              0.0
# 3       Male          Yes   59        No      Executive             11.0
# 4     Female           No   19        No      Marketing              NaN
# ...      ...          ...  ...       ...            ...              ...
# 2622    Male           No   29        No     Healthcare              9.0
# 2623  Female           No   35       Yes         Doctor              1.0
# 2624  Female           No   53       Yes  Entertainment              NaN
# 2625    Male          Yes   47       Yes      Executive              1.0
# 2626  Female           No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1
# 0               Low          1.0  Cat_6
# ...

# %%
df['Age'].unique()
# Out:
# array([36, 37, 69, 59, 19, 47, 61, 50, 22, 27, 18, 20, 45, 55, 88, 63, 42,
#        79, 35, 52, 29, 87, 89, 31, 72, 41, 62, 56, 60, 68, 57, 51, 86, 74,
#        23, 80, 78, 48, 70, 83, 73, 46, 43, 32, 39, 71, 67, 49, 65, 33, 58,
#        30, 21, 26, 81, 28, 76, 85, 66, 53, 40, 25, 77, 75, 82, 84, 38],
#       dtype=int64)

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean()).round(2)

# %%
df['Ever_Married']=df['Ever_Married'].fillna(df['Ever_Married'].mode()[0])

# %%
df['Graduated']=df['Graduated'].fillna(df['Graduated'].mode()[0])

# %%
df['Profession']=df['Profession'].fillna(df['Profession'].mode()[0])

# %%
df['Work_Experience']=df['Work_Experience'].fillna(round(df['Work_Experience'].mean()))

# %%
df['Family_Size']=df['Family_Size'].fillna(round(df['Family_Size'].mean()))

# %%
df['Var_1']=df['Var_1'].fillna(df['Var_1'].mode()[0])

# %%
df.isna().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
cols=['Gender','Ever_Married','Graduated']
for i in cols:
    df[i]=lab.fit_transform(df[i])
df
# Out:
#       Gender  Ever_Married  Age  Graduated     Profession  Work_Experience  \
# 0          0             1   36          1       Engineer              0.0
# 1          1             1   37          1     Healthcare              8.0
# 2          0             1   69          0         Artist              0.0
# 3          1             1   59          0      Executive             11.0
# 4          0             0   19          0      Marketing              3.0
# ...      ...           ...  ...        ...            ...              ...
# 2622       1             0   29          0     Healthcare              9.0
# 2623       0             0   35          1         Doctor              1.0
# 2624       0             0   53          1  Entertainment              3.0
# 2625       1             1   47          1      Executive              1.0
# 2626       0             0   43          1     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1
# ...

# %%
df=pd.get_dummies(df,columns=['Profession','Spending_Score','Var_1'],drop_first=True,dtype=int)

# %%
df.dtypes
# Out:
# Gender                        int32
# Ever_Married                  int32
# Age                           int64
# Graduated                     int32
# Work_Experience             float64
# Family_Size                 float64
# Profession_Doctor             int32
# Profession_Engineer           int32
# Profession_Entertainment      int32
# Profession_Executive          int32
# Profession_Healthcare         int32
# Profession_Homemaker          int32
# Profession_Lawyer             int32
# Profession_Marketing          int32
# Spending_Score_High           int32
# Spending_Score_Low            int32
# Var_1_Cat_2                   int32
# Var_1_Cat_3                   int32
# Var_1_Cat_4                   int32
# Var_1_Cat_5                   int32
# Var_1_Cat_6                   int32
# Var_1_Cat_7                   int32
# dtype: object

# %%
customer_test=df.to_csv('customer_preprocessed_data.csv')

# %%
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Work_Experience  Family_Size  \
# 0          0             1   36          1              0.0          1.0
# 1          1             1   37          1              8.0          4.0
# 2          0             1   69          0              0.0          1.0
# 3          1             1   59          0             11.0          2.0
# 4          0             0   19          0              3.0          4.0
# ...      ...           ...  ...        ...              ...          ...
# 2622       1             0   29          0              9.0          4.0
# 2623       0             0   35          1              1.0          1.0
# 2624       0             0   53          1              3.0          2.0
# 2625       1             1   47          1              1.0          5.0
# 2626       0             0   43          1              9.0          3.0
#
#       Profession_Doctor  Profession_Engineer  Profession_Entertainment  \
# ...
