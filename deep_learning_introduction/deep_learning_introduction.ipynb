# %% [markdown]
# # 🌟 **Machine Learning (ML) vs Deep Learning (DL)**
#
# ## 🔵 **Machine Learning (ML)**
#
# ML is a part of AI where **algorithms learn from data** to make predictions.
#
# ### ✔ Characteristics:
#
# * Works with **smaller datasets**
# * Needs **manual feature extraction**
#   *(You decide what columns/features matter → ex: “word count”, “price”, “age”, etc.)*
# * Models are **simpler** (ex: Logistic Regression, Decision Trees, SVM)
# * **Trains faster**
# * Uses **structured data** mostly
#
# ### ✔ Example:
#
# Predicting house prices using features like area, location, number of rooms.
#
# ---
#
# ## 🔴 **Deep Learning (DL)**
#
# DL is a part of ML that uses **Neural Networks with many layers**.
#
# ### ✔ Characteristics:
#
# * Needs **huge datasets**
# * Does **automatic feature extraction**
#   *(The model learns patterns on its own)*
# * Models are **complex** (CNNs, RNNs, Transformers)
# * **Trains slower**, requires **GPUs**
# * Works great with **images, audio, text**
#
# ### ✔ Example:
#
# Face recognition, object detection, language translation, chatbots.
#
# ---
#
# # ⚡ **Key Differences Summary**
#
# | Feature                | Machine Learning (ML) | Deep Learning (DL)   |
# | ---------------------- | --------------------- | -------------------- |
# | **Part of AI?**        | Yes                   | Yes (subset of ML)   |
# | **Data Need**          | Small–medium          | Very large           |
# | **Feature Extraction** | Manual                | Automatic            |
# | **Training Speed**     | Fast                  | Slow                 |
# | **Hardware**           | CPU                   | GPU/TPU              |
# | **Best For**           | Numbers, tables       | Images, videos, text |
#
# ---
#
# # 🎯 **One-Line Difference**
#
# **ML learns from data using simple algorithms; DL learns using neural networks with many layers that automatically discover patterns.**
#
# ---

# %% [markdown]
#     ML models overfit easily because they have low capacity and small data, while DL models have higher capacity AND better regularization, so even if they memorize data, they still generalize well — so we don’t call them “overfitted”.
