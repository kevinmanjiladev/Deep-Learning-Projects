# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread('image.png')
image
# Out:
# array([[[ 72,  96, 124],
#         [ 70,  94, 122],
#         [ 68,  92, 120],
#         ...,
#         [ 62,  84, 109],
#         [ 62,  84, 109],
#         [ 62,  84, 109]],
#
#        [[ 71,  95, 123],
#         [ 70,  94, 122],
#         [ 68,  92, 120],
#         ...,
#         [ 63,  85, 110],
#         [ 63,  85, 110],
#         [ 63,  85, 110]],
#
#        [[ 71,  95, 123],
#         [ 70,  94, 122],
#         [ 69,  93, 121],
#         ...,
#         [ 63,  85, 110],
#         [ 63,  85, 110],
#         [ 63,  85, 110]],
#
#        ...,
#
#        [[ 44,  54,  61],
#         [ 47,  55,  62],
#         [ 50,  56,  61],
#         ...,
#         [ 76,  87, 107],
#         [ 72,  83, 103],
#         [ 71,  82, 102]],
#
#        [[ 43,  52,  61],
#         [ 46,  54,  61],
#         [ 50,  56,  61],
#         ...,
#         [ 75,  84, 104],
#         [ 71,  80, 100],
#         [ 70,  79,  99]],
#
#        [[ 42,  53,  61],
#         [ 44,  54,  61],
#         [ 50,  56,  61],
#         ...,
#         [ 73,  82, 102],
#         [ 69,  78,  98],
#         [ 68,  77,  97]]], dtype=uint8)

# %%
color_image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(color_image)

# %%
face_data=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face_data
# Out:
# < cv2.CascadeClassifier 000002AC9A0A3A10>

# %%
faces=face_data.detectMultiScale(color_image,minNeighbors=7)
faces
# Out:
# array([[112,  50,  80,  80],
#        [255,  77,  83,  83],
#        [371,  83,  80,  80]])

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(color_image,(x,y),(x+w,y+h),(0,0,255),3)

# %%
plt.imshow(color_image)
