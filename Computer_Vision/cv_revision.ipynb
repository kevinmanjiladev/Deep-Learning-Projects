# %%
import cv2

# %%
image1=cv2.imread('face1.jpg')
image1
# Out:
# array([[[213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255],
#         ...,
#         [213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255]],
#
#        [[213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255],
#         ...,
#         [213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255]],
#
#        [[213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255],
#         ...,
#         [213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255]],
#
#        ...,
#
#        [[213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255],
#         ...,
#         [213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255]],
#
#        [[213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255],
#         ...,
#         [213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255]],
#
#        [[213, 234, 255],
#         [213, 234, 255],
#         [213, 234, 255],
# ...
