# %% [markdown]
# 🌐 What Are Neural Networks?
# ---
# A Neural Network is a computer system that tries to learn and think like the human brain.
#
# It is made of many small units called neurons (just like tiny helpers).

# %% [markdown]
# Your brain has many neurons that work together to help you:
#
#     Recognize a face
#
#     Read letters
#
#     Understand voices
#
#     Solve problems
#
# A neural network tries to do the same thing, but using math instead of biology.

# %% [markdown]
# 🏗️ How does a neural network look?
# ---
# It has layers, like a sandwich:
#
# 1️⃣ Input Layer
#
# Where the information/data enters
# (Like giving a picture, numbers, text)
#
# 2️⃣ Hidden Layers
#
# The brain of the network — where thinking happens
# (Usually many layers)
#
# 3️⃣ Output Layer
#
# Where the answer comes out
# (Like “cat” or “dog”, or a number)
