# %% [markdown]
# 🧠 TensorFlow, Keras, and PyTorch Explained (Very Simple)
#
# ✅ 1. TensorFlow
# ---
#     Think of TensorFlow as a big machine learning engine made by Google.
#
#     It helps you build deep learning models.
#
#     It can run on CPU, GPU, and even mobile phones.
#
#     Very good for large-scale production (Google uses it internally).
#
# 📌 Key point:
# TensorFlow is powerful but can be a bit complex.
#
# ✅ 2. Keras
# ---
# Keras is like a simple and friendly interface built on top of TensorFlow.
#
# Imagine TensorFlow is a big machine ⇒ Keras is the easy dashboard that lets you control the machine.
#
#     Easy to write code
#
#     Very beginner-friendly
#
#     Used for quickly building models
#
# Example:
#
# from tensorflow import keras
#
#
# This means Keras now comes inside TensorFlow (tf.keras).
#
# 📌 Key point:
# Keras = Simple wrapper that makes TensorFlow easier.
#
# ✅ 3. PyTorch
# ---
#     PyTorch is another deep learning framework made by Facebook (Meta).
#
#     More Pythonic → feels like normal Python code
#
#     Very popular in research, universities, and experiments
#
#     Easy to debug
#
#     Dynamic computation graph (flexible)
#
# 📌 Key point:
# PyTorch is simpler for experimentation and research.

# %% [markdown]
# TensorFlow is like a big, powerful engine/machine. On its own, it can build models, but it’s a bit complex.
#
# Keras is like a friendly dashboard or toolkit that sits on top of TensorFlow to make building models much easier. You can use TensorFlow without Keras, but Keras makes life simpler.
#
# PyTorch is another engine/machine. It doesn’t need Keras because it’s already user-friendly and Pythonic. You can build models directly in PyTorch without any extra wrapper.
