# %% [markdown]
# ANN = **Artificial Neural Network**
#
# It is the **basic building block of Deep Learning**.
#
# Think of ANN like a **simple brain-inspired model** that learns patterns from data.
#
# ---
#
# # 🧠 **What is ANN?**
#
# An **Artificial Neural Network (ANN)** is a model made of **neurons (nodes)** arranged in layers.[Mimic structure of neurons]
#
# Each neuron takes input → applies a weight → passes it through an activation function → gives output.
#
# ### ANN = Input Layer → Hidden Layers → Output Layer
#
# Just like the human brain:
#
# * Neurons receive signals
# * Process them
# * Pass signals to the next neuron
#
# ANN works the same way.
#
# ---
#
# # 🏗 **Structure of ANN**
#
# 1. **Input Layer**
#    Receives the features
#    Example: Age, Salary, Gender, Email Text
#
# 2. **Hidden Layers**
#    Performs calculations
#    More layers → more learning power
#
# 3. **Output Layer**
#    Gives prediction
#    Example:
#
#    * Spam / Not Spam
#    * 0 / 1
#    * Class A / Class B / Class C
#
# ---
#
# # 🔥 **Why ANN is used?**
#
# ANN learns complex patterns that normal ML cannot find easily.
#
# ### ANN Works Great For:
#
# * Email spam detection
# * Fraud detection
# * Customer churn prediction
# * Sentiment analysis
# * Simple image classification
# * Pattern recognition
#
# ---
#
# # 📌 **Example**
#
# If you want to classify whether an email is spam:
#
# * Input → email features
# * Hidden layer → learns words & patterns
# * Output layer → “Spam” or “Not Spam”
#
# ---
#
# # ⚡ One-Line Definition
#
# **ANN is a deep learning model made of interconnected neurons that learn patterns from data to make predictions.**
#
# ---

# %% [markdown]
# STRUCTURE OF NUERON
# ---
#
#     Dendrites recieves the signals from the environment.
#
#     Dendrites pass the signals to nucleus.
#
#     When the value of nucleus becomes maximum, it send the information through axons to the dendrite of next nuerons .
#
# (The gap between each nueron is called "SYNAPTIC KNOB")

# %% [markdown]
#     After each transfer of information,the brain recieves information at the end.
#
#     The brain respond through this same channel.

# %% [markdown]
# A **Single Layer Neural Network (SLNN)** is the *simplest* type of neural network.
#
# # 🟦 **single layer network- Definition**
#
# A **single layer neural network** has:
#
# 👉 **One input layer**
# 👉 **One output layer**
# ❌ **No hidden layers**
#
# So there is only **1 layer of weights** between input → output.
#
# ---
#
# # 🧠 **Structure**
#
# ```
# Input Layer  →  Output Layer
# ```
#
# Example:
#
# * Input features: x1, x2, x3
# * Output: y (prediction)
#
# Only one direct connection.
#
# ---
#
# # 🔵 **How a Single Layer Neural Network Works**
#
# Each output neuron does:
#
# [
# y = activation(w_1x_1 + w_2x_2 + ... + b)
# ]
#
# No deeper layers, no complex transformations.
#
# ---
#
# # 📌 **What Can a Single Layer Neural Network Do?**
#
# ✔ Works for **linearly separable problems**
#
# ✔ Can do **binary classification**
#
# ✔ Equivalent to **Logistic Regression** (when activation = sigmoid)
#
# ---
#
# # ❌ **What It Cannot Do**
#
# A single-layer network **cannot learn complex patterns**, because it has:
#
# * No hidden layers
# * No nonlinear transformations
#
# Example:
# It cannot learn XOR problems.
#
# ---
#
# # ⭐ Simple Analogy
#
# A single layer network = **a straight line** separating data.
#
# A multi-layer network = **curved, flexible boundaries** that detect complex patterns.
#
# ---
#
# # 🧪 **Real Example**
#
# Predict if a student will pass or fail using:
#
# * Hours studied
# * Attendance
#
# A single layer network is enough because data is simple.
#
# ---
#
# # 🎯 **One-Line Definition**
#
# **A Single Layer Neural Network contains only an input layer and an output layer, with no hidden layers, and can learn only simple linear patterns.**
#
# ---

# %%
# Input Layer                     Output Neuron
# ------------                    -----------------
#  x1  ------- w1 -----\
#  x2  ------- w2 ------\
#  x3  ------- w3 ------- > ---- ( w1*x1 + w2*x2 + w3*x3 + b ) --> activation --> y
#  ...                    /
#  xn  ------- wn -----/

# %% [markdown]
# A **Multi-Layer Neural Network (MLNN)** is a neural network that has **one or more hidden layers** between the input and output layers.
#
# This is the foundation of **Deep Learning**.
#
# ---
#
# # 🟩 **Multi-layer neural network -Definition**
#
# A **multi-layer neural network** is a neural network with:
#
# * **Input layer**
# * **One or more hidden layers**
# * **Output layer**
#
# It is also called **Fully Connected Nueral Network**
#
# Hidden layers make the network powerful and able to learn complex patterns.
#
# ---
#
# # 🧠 **Structure**
#
# ```
# Input Layer → Hidden Layer 1 → Hidden Layer 2 → ... → Output Layer
# ```
#
# Each hidden layer contains many neurons.
#
# ---
#
# # 🔥 **Why Hidden Layers Matter?**
#
# Hidden layers allow the network to:
#
# * Learn **non-linear patterns**
# * Extract features automatically
# * Solve complex problems
# * Discover deep relationships in data
#
# This is why MLNNs can do things that simple ML and single-layer NN cannot.
#
# ---
#
# # 📌 **Multi-Layer NN Can Learn:**
#
#     ✔ XOR problem
#     ✔ Image classification
#     ✔ Speech recognition
#     ✔ Sentiment analysis
#     ✔ Fraud detection
#     ✔ Language translation
#     ✔ Object detection
#
# ---
#
# # 🔸 **How It Works**
#
# Each neuron in a hidden layer does:
#
# [
# a = activation(Wx + b)
# ]
#
# Activation functions like:
#
# * ReLU
# * Sigmoid
# * Tanh
#
# help the network learn non-linear patterns.
#
# ---
#
# # 🌟 **Why Is It Powerful?**
#
# The more hidden layers and neurons, the more complex the patterns it can learn.
#
# That’s why it’s also called:
#
# 👉 **Deep Neural Network (DNN)**
# when many layers are used.
#
# ---
#
# # 📊 **Example**
#
# Predicting handwritten digits (0–9):
#
# * Input: image pixels
# * Hidden layers: detect edges, shapes
# * Output: final digit prediction
#
# ---
#
# # 🎯 **One-Line Definition**
#
# **A multi-layer neural network has one or more hidden layers, enabling it to learn complex patterns that single-layer networks cannot.**
#
# ---
