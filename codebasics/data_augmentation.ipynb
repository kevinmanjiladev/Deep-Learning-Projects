# %% [markdown]
#  Data Augmentation
# ---
# Used to create new training images by applying:
#
#     Random flip
#
#     Random rotation
#
#     Random zoom
#
# Purpose:
#
#     Reduce overfitting
#
#     Make model stronger
#
#     Improve generalization
