# %% [markdown]
# What is Artificial Intelligence (AI)?
# ---

# %% [markdown]
# AI is the broad idea of making machines think and act like humans.

# %% [markdown]
# Examples:
#
#     Chatbots 🤖
#
#     Face recognition 📷
#
#     Recommendation systems (Netflix, YouTube)

# %% [markdown]
# 🌟 What is Deep Learning? (Explained Like to a Child)
# ---
# Imagine you have a very smart robot friend.
#
# This robot learns things just like you do — by looking, listening, practicing, and making mistakes!
#
# Deep Learning is the brain inside that robot which helps it learn all by itself.
#
# 🤖 How does it learn?
# ----
# Think of its brain as made of many tiny layers, like:
#
#     🍰 Layers of a cake
#     or
#     🏗️ Floors of a building
#
# Each layer helps the robot understand something.
#
# Example:
#
#     First layer sees colors
#
#     Next layer sees shapes
#
#     Next layer sees objects
#
#     Last layer says: “Oh! That is a CAT!” 😺
#
# 🧠 Why is it called “Deep”?
# ---
#
# Because the robot’s brain has many layers, not just 1 or 2 — sometimes hundreds!
#
# More layers = deeper learning = smarter robot
#
# 📝 Simple example
# ---
# If you show the robot:
#
#     🐶 Dog pictures
#     😺 Cat pictures
#
# At first it guesses wrong…
#
# But every time it makes a mistake, it learns and improves.
#
# After seeing many pictures, the robot becomes very good at saying:
#
#     “That is a cat!” 🐱
#     “That is a dog!” 🐶
#
# 🎮 Where do we use Deep Learning?
# ---
# Deep learning is used in many things you already know:
#
#     🚗 Self-driving cars
#
#     📱 Face unlock on your phone
#
#     🎙️ Voice assistants (like Siri, Alexa)
#
#     🎮 Game AIs
#
#     🖼️ Apps that turn your photo into a cartoon
#
#     🤖 ChatGPT 😄
#
# 🎉 In short…
#
# Deep Learning = teaching a computer to learn on its own using lots of examples.
#
# It becomes smarter the more it practices — just like you learning to read, write, or ride a bicycle 🚴‍♂️✨

# %% [markdown]
# ⭐ Why Deep Learning Is Becoming So Popular
# ---
#
#
# 1️⃣ It gives amazing accuracy
# ---
#
# Deep learning can recognize faces, understand speech, translate languages, and play games better than humans in many cases.
#
# That level of accuracy was impossible before.
#
# 2️⃣ It learns automatically
# ---
# Traditional machine learning needs:
#
#     Manual feature engineering
#
#     Lots of cleaning
#
#     Human rules
#
# Deep learning learns features on its own, like:
#
#     Edges
#
#     Shapes
#
#     Patterns
#
#     Meaning
#
# This makes it powerful and easier to scale.
#
# 3️⃣ We have more data than ever
# ---
# We generate massive amounts of data every second:
#
#     Photos
#
#     Videos
#
#     Text
#
#     Sensor data
#
#     Social media
#
#     Medical images
#
# Deep learning LOVES big data — more data = better results.
#
# 4️⃣ GPUs and hardware have become powerful
# ---
# NVIDIA GPUs, TPUs, and cloud computing allow deep learning to train huge models fast.
#
# Earlier, training even a small model took days.
# Now giant models train in hours.
#
# 5️⃣ It works for everything
# ---
# Deep learning is extremely versatile:
#
# | Field           | Use                                       |
# | --------------- | ----------------------------------------- |
# | Computer Vision | Face recognition, medical imaging         |
# | NLP             | ChatGPT, translation                      |
# | Robotics        | Self-driving cars                         |
# | Healthcare      | Disease prediction                        |
# | Finance         | Fraud detection                           |
# | Entertainment   | Recommendation systems (Netflix, YouTube) |
#
#
# Its flexibility makes it the first choice for most AI tasks.
#
# 6️⃣ It keeps improving
# ---
# Every year, new models come out:
#
#     CNNs
#
#     RNNs
#
#     LSTMs
#
#     Transformers
#
#     GPT, BERT, Llama
#
# Each one is more accurate and more efficient.
#
# 7️⃣ Big companies use it
# ---
# Companies like:
#
#     Google
#
#     Meta (Facebook)
#
#     Apple
#
#     Amazon
#
#     Microsoft
#
# use and invest billions in deep learning → this pushes the entire field forward.
#
# 🌟 In simple words
# ---
# Deep learning is popular because it learns on its own, works extremely well, gets better with more data, and solves real-world problems that were impossible before.
